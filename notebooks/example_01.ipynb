# %% [markdown]
# # Example 01 - Maximize C_l / C_d
# - pyfoil: https://github.com/nathanrooy/aerodynamic-shape-optimization
# - simulated annealing: https://github.com/nathanrooy/simulated-annealing

# %%
from scipy.optimize import minimize
from simulated_annealing import sa
from matplotlib import pyplot as plt

from pyfoil.parametric_airfoil import *
from pyfoil.xfoil import *

# %%
# lets read in the naca0012 airfoil geometry
target_airfoil = []
with open('naca0012.txt','r') as foil_txt:
    for i, row in enumerate(foil_txt.readlines()):
        if len(row.split())==2: 
            x, y = row.split()
            target_airfoil.append([float(x), float(y)])    
            
target_airfoil = np.asarray(target_airfoil)

# %%
# reverse fit the parametric airfoil to the naca0012
xpts = np.linspace(0,0.99,100)
initial_airfoil = [0.03, 0.76, 0.08, 0.48, 0.13, 0.15, 0.12, 0.15, -0.08, 0.37, -0.01, 0.69, 0.04]

# %%
# create cost function
def shape_match(control_pts, xpts=xpts, ta=target_airfoil):
    ca = np.array(bezier_airfoil(xpts, munge_ctlpts(control_pts, 3, 3)))
    try:
        return 1000 * np.sum(abs(ca[:,0] - ta[:,0]) + abs(ca[:,1] - ta[:,1]))
    except:
        return 1e10

# %%
# minimize this thing
res = minimize(shape_match, initial_airfoil, method='L-BFGS-B', tol=1e-10, options={'disp': True, 'maxiter':10000})

# %%
res.fun
# Out:
# np.float64(12.515550157584439)

# %%
res.x
# Out:
# array([ 0.02486637,  0.81492863,  0.02714863,  0.42259231,  0.06089415,
#         0.15011154,  0.0589904 ,  0.14205392, -0.05733165,  0.38076424,
#        -0.06204072,  0.74636812, -0.03519086])

# %%
# lets plot the solution

matched_airfoil = np.array(bezier_airfoil(xpts, munge_ctlpts(res.x, 3, 3)))
x0, y0 = zip(*target_airfoil)
x1, y1 = zip(*matched_airfoil)

fig, ax = plt.subplots(figsize=(14,5))
plt.plot(x0, y0, label='target')
plt.plot(x1, y1, label='final')

ax.set_aspect('equal')
plt.ylim(-0.15,0.15)
plt.legend()
plt.show()

# %%
# the initial airfoil used panels with constant spacing
# lets be smart and change this to cosine spacing
# while using the control points we just solved for.

num_panels = 60
num_pts = num_panels + 1

x_rad = np.linspace(0, pi, num_pts)
x_cos = (np.cos(x_rad) / 2) + 0.5
x_cos = x_cos[1:]

# matched airfoil with cosine spacing
initial_airfoil = np.array(bezier_airfoil(x_cos, munge_ctlpts(res.x, 3, 3)))

# %%
# final sanity check

x0, y0 = zip(*matched_airfoil)
x1, y1 = zip(*initial_airfoil)

fig, ax = plt.subplots(figsize=(14,5))
plt.plot(x0, y0, label='equal spacing')
plt.plot(x1, y1, label='cosine spacing')

ax.set_aspect('equal')
plt.ylim(-0.15,0.15)
plt.legend()
plt.show()

# %%
# plot final airfoil with control points
x0, y0=zip(*np.array(munge_ctlpts(res.x, 3, 3)))
x1, y1 = zip(*initial_airfoil)


fig, ax = plt.subplots(figsize=(14,5))
plt.plot(x0, y0, color='#2c3e50', linewidth=1.5, linestyle='--', label='bezier segment')
plt.plot(x1, y1, color='#2980b9', label='parametric naca0012', linewidth=2)
plt.plot(x0, y0, 'o', mfc='none', mec='r', markersize=8, label='control pts')

ax.set_aspect('equal')
plt.ylim(-0.15, 0.15)
plt.legend()

plt.show()

# %%
def cost_function(x, x_coords=x_cos):
    airfoil_file = 'airfoil.txt'
    
    try:
        # munge x-vector into bezier format
        control_pts = munge_ctlpts(x, 3, 3)

        # generate new airfoil
        curve = bezier_airfoil(x_coords, control_pts)

        # output airfoil to csv
        with open(airfoil_file,'w') as out_file:
            out_file.write('x,y\n')
            for item in curve:
                out_file.write(f'{item[0]},{item[1]}\n')

        # run xfoil and collect results
        results_dict = run_xfoil()
        
        # determine cost
        cost = results_dict['cl'] / results_dict['cd']
        if results_dict['cl'] < 0: cost = 0.01
        
    except:
        cost = 0.01
    
    # remove airfoil file
    os.system(f'rm -rf {airfoil_file}')

    print(f'> cl/cd={cost:0.4f} -> cost_func={1000.0 / cost:0.4f}')
    
    return 1000.0 / cost

# %%
opt = sa.minimize(cost_function, res.x, opt_mode = 'continuous', step_max=500, t_max=2.5, t_min=0, damping=0.01)
# Out:
# > cl/cd=0.3166 -> cost_func=3158.8235
# > cl/cd=2.3105 -> cost_func=432.8000
# > cl/cd=2.3818 -> cost_func=419.8529
# > cl/cd=8.7115 -> cost_func=114.7903
# > cl/cd=0.3512 -> cost_func=2847.0588
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.2832 -> cost_func=3530.7692
# > cl/cd=9.5279 -> cost_func=104.9550
# > cl/cd=3.5436 -> cost_func=282.1990
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0638 -> cost_func=15666.6667
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=4.1290 -> cost_func=242.1875
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=1.4737 -> cost_func=678.5714
# > cl/cd=5.0992 -> cost_func=196.1089
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=3.6021 -> cost_func=277.6190
# > cl/cd=4.1598 -> cost_func=240.3941
# > cl/cd=1.8388 -> cost_func=543.8202
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.4734 -> cost_func=2112.5000
# > cl/cd=9.7257 -> cost_func=102.8200
# > cl/cd=6.6329 -> cost_func=150.7645
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.7597 -> cost_func=1316.2791
# > cl/cd=1.0376 -> cost_func=963.7931
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=8.3082 -> cost_func=120.3629
# > cl/cd=7.4587 -> cost_func=134.0708
# > cl/cd=11.9371 -> cost_func=83.7725
# > cl/cd=22.1377 -> cost_func=45.1718
# > cl/cd=20.6427 -> cost_func=48.4432
# > cl/cd=22.6325 -> cost_func=44.1843
# > cl/cd=16.7966 -> cost_func=59.5358
# > cl/cd=26.5928 -> cost_func=37.6041
# > cl/cd=36.0589 -> cost_func=27.7324
# > cl/cd=32.6376 -> cost_func=30.6395
# > cl/cd=26.8654 -> cost_func=37.2226
# > cl/cd=20.3585 -> cost_func=49.1196
# > cl/cd=30.1359 -> cost_func=33.1830
# > cl/cd=28.9209 -> cost_func=34.5771
# > cl/cd=25.4059 -> cost_func=39.3609
# > cl/cd=21.4448 -> cost_func=46.6314
# > cl/cd=27.2917 -> cost_func=36.6412
# > cl/cd=31.2294 -> cost_func=32.0212
# > cl/cd=17.2521 -> cost_func=57.9639
# > cl/cd=35.4563 -> cost_func=28.2038
# > cl/cd=41.1700 -> cost_func=24.2895
# > cl/cd=32.5539 -> cost_func=30.7183
# > cl/cd=29.8805 -> cost_func=33.4666
# > cl/cd=33.5191 -> cost_func=29.8337
# > cl/cd=30.6108 -> cost_func=32.6682
# > cl/cd=37.4749 -> cost_func=26.6845
# > cl/cd=28.7337 -> cost_func=34.8023
# > cl/cd=31.5428 -> cost_func=31.7030
# > cl/cd=33.3926 -> cost_func=29.9468
# > cl/cd=26.2109 -> cost_func=38.1520
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=28.3458 -> cost_func=35.2787
# > cl/cd=34.7181 -> cost_func=28.8034
# > cl/cd=31.8182 -> cost_func=31.4286
# > cl/cd=31.9762 -> cost_func=31.2732
# > cl/cd=30.7133 -> cost_func=32.5592
# > cl/cd=33.4771 -> cost_func=29.8711
# > cl/cd=37.8523 -> cost_func=26.4185
# > cl/cd=36.6667 -> cost_func=27.2727
# > cl/cd=30.2051 -> cost_func=33.1070
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=36.3006 -> cost_func=27.5478
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=29.2347 -> cost_func=34.2059
# > cl/cd=30.5180 -> cost_func=32.7675
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=33.3285 -> cost_func=30.0043
# > cl/cd=28.5377 -> cost_func=35.0414
# > cl/cd=27.9820 -> cost_func=35.7373
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=33.5646 -> cost_func=29.7933
# > cl/cd=27.4321 -> cost_func=36.4536
# > cl/cd=36.2219 -> cost_func=27.6076
# > cl/cd=24.8739 -> cost_func=40.2027
# > cl/cd=41.1339 -> cost_func=24.3109
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=39.0194 -> cost_func=25.6283
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=42.8984 -> cost_func=23.3109
# > cl/cd=36.8627 -> cost_func=27.1277
# > cl/cd=38.9421 -> cost_func=25.6792
# > cl/cd=30.8742 -> cost_func=32.3895
# > cl/cd=36.7445 -> cost_func=27.2150
# > cl/cd=42.8478 -> cost_func=23.3384
# > cl/cd=46.6421 -> cost_func=21.4398
# > cl/cd=42.9360 -> cost_func=23.2905
# > cl/cd=47.6799 -> cost_func=20.9732
# > cl/cd=43.7834 -> cost_func=22.8397
# > cl/cd=43.0657 -> cost_func=23.2203
# > cl/cd=41.6687 -> cost_func=23.9988
# > cl/cd=42.2527 -> cost_func=23.6671
# > cl/cd=46.8986 -> cost_func=21.3226
# > cl/cd=49.8153 -> cost_func=20.0742
# > cl/cd=50.7126 -> cost_func=19.7190
# > cl/cd=49.2271 -> cost_func=20.3140
# > cl/cd=48.2557 -> cost_func=20.7230
# > cl/cd=56.5984 -> cost_func=17.6684
# > cl/cd=49.7810 -> cost_func=20.0880
# > cl/cd=63.7538 -> cost_func=15.6853
# > cl/cd=62.3752 -> cost_func=16.0320
# > cl/cd=49.6450 -> cost_func=20.1430
# > cl/cd=69.6907 -> cost_func=14.3491
# > cl/cd=72.5550 -> cost_func=13.7826
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=50.2466 -> cost_func=19.9018
# > cl/cd=51.9276 -> cost_func=19.2576
# > cl/cd=69.9827 -> cost_func=14.2892
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=45.5273 -> cost_func=21.9649
# > cl/cd=76.6551 -> cost_func=13.0455
# > cl/cd=74.7530 -> cost_func=13.3774
# > cl/cd=76.4676 -> cost_func=13.0774
# > cl/cd=74.0816 -> cost_func=13.4986
# > cl/cd=73.8345 -> cost_func=13.5438
# > cl/cd=70.8983 -> cost_func=14.1047
# > cl/cd=75.7939 -> cost_func=13.1937
# > cl/cd=78.6667 -> cost_func=12.7119
# > cl/cd=75.3675 -> cost_func=13.2683
# > cl/cd=76.1905 -> cost_func=13.1250
# > cl/cd=73.5495 -> cost_func=13.5963
# > cl/cd=73.0449 -> cost_func=13.6902
# > cl/cd=64.8414 -> cost_func=15.4222
# > cl/cd=69.2699 -> cost_func=14.4363
# > cl/cd=72.9076 -> cost_func=13.7160
# > cl/cd=76.8750 -> cost_func=13.0081
# > cl/cd=74.2540 -> cost_func=13.4673
# > cl/cd=77.3344 -> cost_func=12.9309
# > cl/cd=71.9818 -> cost_func=13.8924
# > cl/cd=67.0045 -> cost_func=14.9244
# > cl/cd=63.5926 -> cost_func=15.7251
# > cl/cd=61.6170 -> cost_func=16.2293
# > cl/cd=61.7493 -> cost_func=16.1945
# > cl/cd=62.1429 -> cost_func=16.0920
# > cl/cd=65.6768 -> cost_func=15.2261
# > cl/cd=68.3929 -> cost_func=14.6214
# > cl/cd=73.0657 -> cost_func=13.6863
# > cl/cd=74.6199 -> cost_func=13.4013
# > cl/cd=76.9637 -> cost_func=12.9931
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=71.2052 -> cost_func=14.0439
# > cl/cd=68.1977 -> cost_func=14.6633
# > cl/cd=68.6402 -> cost_func=14.5687
# > cl/cd=72.0544 -> cost_func=13.8784
# > cl/cd=73.0015 -> cost_func=13.6983
# > cl/cd=68.6063 -> cost_func=14.5759
# > cl/cd=68.2242 -> cost_func=14.6576
# > cl/cd=63.2808 -> cost_func=15.8026
# > cl/cd=66.9453 -> cost_func=14.9376
# > cl/cd=65.9571 -> cost_func=15.1614
# > cl/cd=62.3839 -> cost_func=16.0298
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=62.1142 -> cost_func=16.0994
# > cl/cd=55.4167 -> cost_func=18.0451
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=58.6425 -> cost_func=17.0525
# > cl/cd=56.8223 -> cost_func=17.5987
# > cl/cd=56.5976 -> cost_func=17.6686
# > cl/cd=59.0299 -> cost_func=16.9406
# > cl/cd=62.4689 -> cost_func=16.0080
# > cl/cd=58.0775 -> cost_func=17.2184
# > cl/cd=56.9782 -> cost_func=17.5506
# > cl/cd=52.0741 -> cost_func=19.2034
# > cl/cd=50.9012 -> cost_func=19.6459
# > cl/cd=47.5588 -> cost_func=21.0266
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=47.3633 -> cost_func=21.1134
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=47.3677 -> cost_func=21.1114
# > cl/cd=52.3881 -> cost_func=19.0883
# > cl/cd=48.7500 -> cost_func=20.5128
# > cl/cd=46.0231 -> cost_func=21.7282
# > cl/cd=49.3484 -> cost_func=20.2641
# > cl/cd=43.6072 -> cost_func=22.9320
# > cl/cd=47.5104 -> cost_func=21.0480
# > cl/cd=56.3953 -> cost_func=17.7320
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=59.7329 -> cost_func=16.7412
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=63.5625 -> cost_func=15.7325
# > cl/cd=60.8359 -> cost_func=16.4377
# > cl/cd=60.4489 -> cost_func=16.5429
# > cl/cd=55.3421 -> cost_func=18.0694
# > cl/cd=45.3259 -> cost_func=22.0624
# > cl/cd=60.8012 -> cost_func=16.4470
# > cl/cd=54.5357 -> cost_func=18.3366
# > cl/cd=55.1448 -> cost_func=18.1341
# > cl/cd=45.9133 -> cost_func=21.7802
# > cl/cd=58.7994 -> cost_func=17.0070
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=54.4798 -> cost_func=18.3554
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=50.3810 -> cost_func=19.8488
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=57.1586 -> cost_func=17.4952
# > cl/cd=56.9624 -> cost_func=17.5555
# > cl/cd=56.5860 -> cost_func=17.6722
# > cl/cd=46.1168 -> cost_func=21.6841
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=52.8699 -> cost_func=18.9144
# > cl/cd=60.1038 -> cost_func=16.6379
# > cl/cd=54.1060 -> cost_func=18.4822
# > cl/cd=50.4306 -> cost_func=19.8292
# > cl/cd=60.1902 -> cost_func=16.6140
# > cl/cd=61.3599 -> cost_func=16.2973
# > cl/cd=60.1292 -> cost_func=16.6309
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=49.2721 -> cost_func=20.2955
# > cl/cd=54.2955 -> cost_func=18.4177
# > cl/cd=53.6531 -> cost_func=18.6382
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=58.3818 -> cost_func=17.1286
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=54.3230 -> cost_func=18.4084
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=63.8409 -> cost_func=15.6639
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=58.2976 -> cost_func=17.1534
# > cl/cd=64.6395 -> cost_func=15.4704
# > cl/cd=63.6649 -> cost_func=15.7073
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=66.4454 -> cost_func=15.0500
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=66.4276 -> cost_func=15.0540
# > cl/cd=65.0892 -> cost_func=15.3635
# > cl/cd=68.1974 -> cost_func=14.6633
# > cl/cd=65.4956 -> cost_func=15.2682
# > cl/cd=71.3185 -> cost_func=14.0216
# > cl/cd=70.2821 -> cost_func=14.2284
# > cl/cd=60.8214 -> cost_func=16.4416
# > cl/cd=72.0390 -> cost_func=13.8814
# > cl/cd=77.0153 -> cost_func=12.9844
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=80.6770 -> cost_func=12.3951
# > cl/cd=76.3165 -> cost_func=13.1033
# > cl/cd=68.7081 -> cost_func=14.5543
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=72.5916 -> cost_func=13.7757
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=73.2373 -> cost_func=13.6542
# > cl/cd=77.0678 -> cost_func=12.9756
# > cl/cd=78.4895 -> cost_func=12.7406
# > cl/cd=82.8790 -> cost_func=12.0658
# > cl/cd=86.6189 -> cost_func=11.5448
# > cl/cd=82.0822 -> cost_func=12.1829
# > cl/cd=80.5556 -> cost_func=12.4138
# > cl/cd=85.4741 -> cost_func=11.6994
# > cl/cd=82.7706 -> cost_func=12.0816
# > cl/cd=75.5691 -> cost_func=13.2329
# > cl/cd=79.1268 -> cost_func=12.6379
# > cl/cd=81.5515 -> cost_func=12.2622
# > cl/cd=84.1379 -> cost_func=11.8852
# > cl/cd=82.1986 -> cost_func=12.1657
# > cl/cd=87.6647 -> cost_func=11.4071
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=85.3765 -> cost_func=11.7128
# > cl/cd=79.3723 -> cost_func=12.5988
# > cl/cd=89.0259 -> cost_func=11.2327
# > cl/cd=90.1961 -> cost_func=11.0870
# > cl/cd=86.9760 -> cost_func=11.4974
# > cl/cd=86.8650 -> cost_func=11.5121
# > cl/cd=91.7147 -> cost_func=10.9034
# > cl/cd=78.8285 -> cost_func=12.6858
# > cl/cd=94.8933 -> cost_func=10.5382
# > cl/cd=95.0952 -> cost_func=10.5158
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=89.5964 -> cost_func=11.1612
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=103.1738 -> cost_func=9.6924
# > cl/cd=99.2528 -> cost_func=10.0753
# > cl/cd=100.6331 -> cost_func=9.9371
# > cl/cd=98.0583 -> cost_func=10.1980
# > cl/cd=104.1842 -> cost_func=9.5984
# > cl/cd=107.8964 -> cost_func=9.2681
# > cl/cd=109.0256 -> cost_func=9.1722
# > cl/cd=112.7787 -> cost_func=8.8669
# > cl/cd=111.0217 -> cost_func=9.0073
# > cl/cd=100.6380 -> cost_func=9.9366
# > cl/cd=112.0094 -> cost_func=8.9278
# > cl/cd=111.7920 -> cost_func=8.9452
# > cl/cd=115.7810 -> cost_func=8.6370
# > cl/cd=107.4962 -> cost_func=9.3027
# > cl/cd=114.6044 -> cost_func=8.7257
# > cl/cd=108.9825 -> cost_func=9.1758
# > cl/cd=103.6309 -> cost_func=9.6496
# > cl/cd=100.3400 -> cost_func=9.9661
# > cl/cd=110.4313 -> cost_func=9.0554
# > cl/cd=107.7987 -> cost_func=9.2765
# > cl/cd=91.5934 -> cost_func=10.9178
# > cl/cd=108.0488 -> cost_func=9.2551
# > cl/cd=101.7949 -> cost_func=9.8237
# > cl/cd=104.0549 -> cost_func=9.6103
# > cl/cd=95.3253 -> cost_func=10.4904
# > cl/cd=89.1360 -> cost_func=11.2188
# > cl/cd=94.8624 -> cost_func=10.5416
# > cl/cd=95.0150 -> cost_func=10.5247
# > cl/cd=89.6313 -> cost_func=11.1568
# > cl/cd=89.7388 -> cost_func=11.1435
# > cl/cd=88.0899 -> cost_func=11.3520
# > cl/cd=80.2989 -> cost_func=12.4535
# > cl/cd=86.2921 -> cost_func=11.5885
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=93.7707 -> cost_func=10.6643
# > cl/cd=89.7030 -> cost_func=11.1479
# > cl/cd=91.5297 -> cost_func=10.9254
# > cl/cd=92.4520 -> cost_func=10.8164
# > cl/cd=96.2250 -> cost_func=10.3923
# > cl/cd=83.4838 -> cost_func=11.9784
# > cl/cd=87.7909 -> cost_func=11.3907
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=105.0487 -> cost_func=9.5194
# > cl/cd=106.7810 -> cost_func=9.3650
# > cl/cd=102.0161 -> cost_func=9.8024
# > cl/cd=99.7856 -> cost_func=10.0215
# > cl/cd=102.6797 -> cost_func=9.7390
# > cl/cd=102.0331 -> cost_func=9.8007
# > cl/cd=97.1870 -> cost_func=10.2894
# > cl/cd=101.8874 -> cost_func=9.8148
# > cl/cd=106.1681 -> cost_func=9.4190
# > cl/cd=104.4556 -> cost_func=9.5734
# > cl/cd=100.7667 -> cost_func=9.9239
# > cl/cd=107.3920 -> cost_func=9.3117
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=101.4944 -> cost_func=9.8528
# > cl/cd=108.5481 -> cost_func=9.2125
# > cl/cd=109.4243 -> cost_func=9.1387
# > cl/cd=109.9515 -> cost_func=9.0949
# > cl/cd=100.9204 -> cost_func=9.9088
# > cl/cd=106.5161 -> cost_func=9.3882
# > cl/cd=107.4799 -> cost_func=9.3041
# > cl/cd=104.5136 -> cost_func=9.5681
# > cl/cd=101.5244 -> cost_func=9.8498
# > cl/cd=102.5811 -> cost_func=9.7484
# > cl/cd=98.5997 -> cost_func=10.1420
# > cl/cd=95.6361 -> cost_func=10.4563
# > cl/cd=99.0762 -> cost_func=10.0932
# > cl/cd=99.1818 -> cost_func=10.0825
# > cl/cd=98.1682 -> cost_func=10.1866
# > cl/cd=98.5845 -> cost_func=10.1436
# > cl/cd=100.9466 -> cost_func=9.9062
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=99.0882 -> cost_func=10.0920
# > cl/cd=94.5007 -> cost_func=10.5819
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=97.7280 -> cost_func=10.2325
# > cl/cd=94.2033 -> cost_func=10.6153
# > cl/cd=97.7504 -> cost_func=10.2301
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=99.9251 -> cost_func=10.0075
# > cl/cd=100.3161 -> cost_func=9.9685
# > cl/cd=104.8126 -> cost_func=9.5408
# > cl/cd=102.8943 -> cost_func=9.7187
# > cl/cd=98.8674 -> cost_func=10.1146
# > cl/cd=103.3535 -> cost_func=9.6755
# > cl/cd=102.0795 -> cost_func=9.7963
# > cl/cd=98.6617 -> cost_func=10.1357
# > cl/cd=96.4596 -> cost_func=10.3670
# > cl/cd=93.6795 -> cost_func=10.6747
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=98.3689 -> cost_func=10.1658
# > cl/cd=99.4444 -> cost_func=10.0559
# > cl/cd=97.6618 -> cost_func=10.2394
# > cl/cd=101.3478 -> cost_func=9.8670
# > cl/cd=102.8316 -> cost_func=9.7246
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=98.8593 -> cost_func=10.1154
# > cl/cd=73.4348 -> cost_func=13.6175
# > cl/cd=91.1628 -> cost_func=10.9694
# > cl/cd=102.6794 -> cost_func=9.7391
# > cl/cd=103.6241 -> cost_func=9.6503
# > cl/cd=107.9610 -> cost_func=9.2626
# > cl/cd=103.0117 -> cost_func=9.7076
# > cl/cd=107.3692 -> cost_func=9.3137
# > cl/cd=103.4522 -> cost_func=9.6663
# > cl/cd=100.7925 -> cost_func=9.9214
# > cl/cd=84.3855 -> cost_func=11.8504
# > cl/cd=92.7016 -> cost_func=10.7873
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=105.3264 -> cost_func=9.4943
# > cl/cd=106.1712 -> cost_func=9.4188
# > cl/cd=72.2432 -> cost_func=13.8421
# > cl/cd=103.0126 -> cost_func=9.7076
# > cl/cd=107.3723 -> cost_func=9.3134
# > cl/cd=105.3249 -> cost_func=9.4944
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=98.4097 -> cost_func=10.1616
# > cl/cd=104.0580 -> cost_func=9.6100
# > cl/cd=55.0398 -> cost_func=18.1687
# > cl/cd=100.6512 -> cost_func=9.9353
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=104.1241 -> cost_func=9.6039
# > cl/cd=96.5092 -> cost_func=10.3617
# > cl/cd=99.1509 -> cost_func=10.0856
# > cl/cd=103.2192 -> cost_func=9.6881
# > cl/cd=108.2906 -> cost_func=9.2344
# > cl/cd=104.5194 -> cost_func=9.5676
# > cl/cd=113.2945 -> cost_func=8.8266
# > cl/cd=111.5524 -> cost_func=8.9644
# > cl/cd=115.2915 -> cost_func=8.6737
# > cl/cd=115.2121 -> cost_func=8.6796
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=118.7613 -> cost_func=8.4202
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=122.8197 -> cost_func=8.1420
# > cl/cd=119.2462 -> cost_func=8.3860
# > cl/cd=120.0000 -> cost_func=8.3333
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=124.6130 -> cost_func=8.0248
# > cl/cd=116.8116 -> cost_func=8.5608
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=125.7729 -> cost_func=7.9508
# > cl/cd=124.0185 -> cost_func=8.0633
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=121.3450 -> cost_func=8.2410
# > cl/cd=117.2452 -> cost_func=8.5291
# > cl/cd=120.8836 -> cost_func=8.2724
# > cl/cd=119.6814 -> cost_func=8.3555
# > cl/cd=116.7901 -> cost_func=8.5624
# > cl/cd=122.1007 -> cost_func=8.1900
# > cl/cd=125.5804 -> cost_func=7.9630
# > cl/cd=123.4621 -> cost_func=8.0997
# > cl/cd=128.0419 -> cost_func=7.8099
# > cl/cd=125.0073 -> cost_func=7.9995
# > cl/cd=129.8943 -> cost_func=7.6986
# > cl/cd=128.9280 -> cost_func=7.7563
# > cl/cd=127.7941 -> cost_func=7.8251
# > cl/cd=117.1162 -> cost_func=8.5385
# > cl/cd=132.3459 -> cost_func=7.5560
# > cl/cd=134.3884 -> cost_func=7.4411
# > cl/cd=141.0764 -> cost_func=7.0884
# > cl/cd=138.5179 -> cost_func=7.2193
# > cl/cd=139.3849 -> cost_func=7.1744
# > cl/cd=78.7800 -> cost_func=12.6936
# > cl/cd=131.5396 -> cost_func=7.6023
# > cl/cd=137.7080 -> cost_func=7.2617
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=140.3205 -> cost_func=7.1265
# > cl/cd=139.4277 -> cost_func=7.1722
# > cl/cd=139.7937 -> cost_func=7.1534
# > cl/cd=137.9939 -> cost_func=7.2467
# > cl/cd=87.6228 -> cost_func=11.4126
# > cl/cd=136.3328 -> cost_func=7.3350
# > cl/cd=141.5421 -> cost_func=7.0650
# > cl/cd=95.4661 -> cost_func=10.4749
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=98.0184 -> cost_func=10.2022
# > cl/cd=141.9599 -> cost_func=7.0442
# > cl/cd=138.2309 -> cost_func=7.2343
# > cl/cd=140.6098 -> cost_func=7.1119
# > cl/cd=135.1802 -> cost_func=7.3975
# > cl/cd=133.6217 -> cost_func=7.4838
# > cl/cd=143.5950 -> cost_func=6.9640
# > cl/cd=138.7481 -> cost_func=7.2073
# > cl/cd=142.7663 -> cost_func=7.0045
# > cl/cd=142.9575 -> cost_func=6.9951
# > cl/cd=141.6155 -> cost_func=7.0614
# > cl/cd=142.8874 -> cost_func=6.9985
# > cl/cd=136.8116 -> cost_func=7.3093
# > cl/cd=135.1491 -> cost_func=7.3992

# %%
opt.results()
# Out:
# +------------------------ RESULTS -------------------------+
#
#       opt.mode: continuous
# cooling sched.: linear additive cooling
#        damping: 0.01
#
#   initial temp: 2.5
#     final temp: 0.005000
#      max steps: 500
#     final step: 500
#
#   final energy: 6.964032
#
# +-------------------------- END ---------------------------+

# %%
# initial
# note that the initial airfoil did produce just the smallest bit of lift 
# which is why the cost function is greater than zero...
cost_function(opt.x0)
# Out:
# > cl/cd=0.3166 -> cost_func=3158.8235
# 3158.823529411765

# %%
# final
cost_function(opt.best_state)
# Out:
# > cl/cd=143.5950 -> cost_func=6.9640
# 6.964031923034875

# %%
airfoil_initial = bezier_airfoil(x_cos, munge_ctlpts(opt.x0, 3, 3))
airfoil_final   = bezier_airfoil(x_cos, munge_ctlpts(opt.best_state, 3, 3))

fig, ax = plt.subplots(figsize=(14,5))

x_initial, y_initial=zip(*airfoil_initial)
x_final, y_final=zip(*airfoil_final)

plt.plot(x_initial, y_initial, label='initial')
plt.plot(x_final, y_final, label='final')
plt.title('results')

plt.legend()
plt.ylim(-0.15, 0.15)
ax.set_aspect('equal')
plt.show()
