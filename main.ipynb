# %% [markdown]
# # NACA0012 - Maximize C_l / C_d

# %%
from scipy.optimize import minimize
from simulated_annealing import sa
from matplotlib import pyplot as plt

from pyfoil.parametric_airfoil import *
from pyfoil.xfoil import *

# %%
# lets read in the naca0012 airfoil geometry
target_airfoil = []
with open('naca0012.txt','r') as foil_txt:
    for i, row in enumerate(foil_txt.readlines()):
        if len(row.split())==2: 
            x, y = row.split()
            target_airfoil.append([float(x), float(y)])    
            
target_airfoil = np.asarray(target_airfoil)

# %%
# reverse fit the parametric airfoil to the naca0012
xpts = np.linspace(0,0.99,100)
initial_airfoil = [0.03, 0.76, 0.08, 0.48, 0.13, 0.15, 0.12, 0.15, -0.08, 0.37, -0.01, 0.69, 0.04]

# %%
# create cost function
def shape_match(control_pts, xpts=xpts, ta=target_airfoil):
    ca = np.array(bezier_airfoil(xpts, munge_ctlpts(control_pts, 3, 3)))
    try:
        return 1000 * np.sum(abs(ca[:,0] - ta[:,0]) + abs(ca[:,1] - ta[:,1]))
    except:
        return 1e10

# %%
# minimize this thing
res = minimize(shape_match, initial_airfoil, method='L-BFGS-B', tol=1e-10, options={'disp': True, 'maxiter':10000})

# %%
res.fun
# Out:
# 12.515550157584439

# %%
res.x
# Out:
# array([ 0.02486637,  0.81492863,  0.02714863,  0.42259231,  0.06089415,
#         0.15011154,  0.0589904 ,  0.14205392, -0.05733165,  0.38076424,
#        -0.06204072,  0.74636812, -0.03519086])

# %%
# lets plot the solution

matched_airfoil = np.array(bezier_airfoil(xpts, munge_ctlpts(res.x, 3, 3)))
x0, y0 = zip(*target_airfoil)
x1, y1 = zip(*matched_airfoil)

fig, ax = plt.subplots(figsize=(14,5))
plt.plot(x0, y0, label='target')
plt.plot(x1, y1, label='final')

ax.set_aspect('equal')
plt.ylim(-0.15,0.15)
plt.legend()
plt.show()

# %%
# the initial airfoil used panels with constant spacing
# lets be smart and change this to cosine spacing
# while using the control points we just solved for.

num_panels = 60
num_pts = num_panels + 1

x_rad = np.linspace(0, pi, num_pts)
x_cos = (np.cos(x_rad) / 2) + 0.5
x_cos = x_cos[1:]

# matched airfoil with cosine spacing
initial_airfoil = np.array(bezier_airfoil(x_cos, munge_ctlpts(res.x, 3, 3)))

# %%
# final sanity check

x0, y0 = zip(*matched_airfoil)
x1, y1 = zip(*initial_airfoil)

fig, ax = plt.subplots(figsize=(14,5))
plt.plot(x0, y0, label='equal spacing')
plt.plot(x1, y1, label='cosine spacing')

ax.set_aspect('equal')
plt.ylim(-0.15,0.15)
plt.legend()
plt.show()

# %%
# plot final airfoil with control points
x0, y0=zip(*np.array(munge_ctlpts(res.x, 3, 3)))
x1, y1 = zip(*initial_airfoil)


fig, ax = plt.subplots(figsize=(14,5))
plt.plot(x0, y0, color='#2c3e50', linewidth=1.5, linestyle='--', label='bezier segment')
plt.plot(x1, y1, color='#2980b9', label='parametric naca0012', linewidth=2)
plt.plot(x0, y0, 'o', mfc='none', mec='r', markersize=8, label='control pts')

ax.set_aspect('equal')
plt.ylim(-0.15, 0.15)
plt.legend()

plt.show()

# %%
def cost_function(x, x_coords=x_cos):
    airfoil_file = 'airfoil.txt'
    
    try:
        # munge x-vector into bezier format
        control_pts = munge_ctlpts(x, 3, 3)

        # generate new airfoil
        curve = bezier_airfoil(x_coords, control_pts)

        # output airfoil to csv
        with open(airfoil_file,'w') as out_file:
            out_file.write('x,y\n')
            for item in curve:
                out_file.write(f'{item[0]},{item[1]}\n')

        # run xfoil and collect results
        results_dict = run_xfoil()
        
        # determine cost
        cost = results_dict['cl'] / results_dict['cd']
        if results_dict['cl'] < 0: cost = 0.01
        
    except:
        cost = 0.01
    
    # remove airfoil file
    os.remove(airfoil_file)

    print(f'> cl/cd={cost:0.4f} -> cost_func={1000.0 / cost:0.4f}')
    
    return 1000.0 / cost

# %%
opt = sa.minimize(cost_function, res.x, opt_mode = 'continuous', step_max=500, t_max=2.5, t_min=0, damping=0.01)
# Out:
# > cl/cd=0.3166 -> cost_func=3158.8235
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=2.7273 -> cost_func=366.6667
# > cl/cd=2.1667 -> cost_func=461.5385
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=3.4286 -> cost_func=291.6667
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=1.7997 -> cost_func=555.6604
# > cl/cd=7.0696 -> cost_func=141.4508
# > cl/cd=6.8024 -> cost_func=147.0060
# > cl/cd=6.0594 -> cost_func=165.0327
# > cl/cd=0.1064 -> cost_func=9400.0000
# > cl/cd=3.1801 -> cost_func=314.4509
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=5.2273 -> cost_func=191.3043
# > cl/cd=3.9388 -> cost_func=253.8835
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=1.4677 -> cost_func=681.3333
# > cl/cd=8.8008 -> cost_func=113.6264
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=5.8254 -> cost_func=171.6612
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=6.1497 -> cost_func=162.6087
# > cl/cd=2.2985 -> cost_func=435.0746
# > cl/cd=2.0745 -> cost_func=482.0513
# > cl/cd=3.5877 -> cost_func=278.7330
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=2.3404 -> cost_func=427.2727
# > cl/cd=0.3671 -> cost_func=2723.8095
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=5.4219 -> cost_func=184.4371
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0683 -> cost_func=14650.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=2.7504 -> cost_func=363.5802
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=2.2631 -> cost_func=441.8803
# > cl/cd=3.7870 -> cost_func=264.0625
# > cl/cd=4.9060 -> cost_func=203.8328
# > cl/cd=2.3193 -> cost_func=431.1594
# > cl/cd=0.2632 -> cost_func=3800.0000
# > cl/cd=0.5367 -> cost_func=1863.3333
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=5.1695 -> cost_func=193.4426
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=1.7138 -> cost_func=583.5052
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=5.4405 -> cost_func=183.8068
# > cl/cd=11.9551 -> cost_func=83.6461
# > cl/cd=7.5510 -> cost_func=132.4324
# > cl/cd=10.6912 -> cost_func=93.5345
# > cl/cd=11.2019 -> cost_func=89.2704
# > cl/cd=14.2270 -> cost_func=70.2890
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=11.7550 -> cost_func=85.0704
# > cl/cd=22.9715 -> cost_func=43.5321
# > cl/cd=26.9596 -> cost_func=37.0926
# > cl/cd=29.4364 -> cost_func=33.9716
# > cl/cd=24.6561 -> cost_func=40.5579
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=23.0532 -> cost_func=43.3780
# > cl/cd=29.3369 -> cost_func=34.0867
# > cl/cd=27.5503 -> cost_func=36.2973
# > cl/cd=23.4586 -> cost_func=42.6282
# > cl/cd=33.3816 -> cost_func=29.9567
# > cl/cd=36.1905 -> cost_func=27.6316
# > cl/cd=39.5212 -> cost_func=25.3029
# > cl/cd=37.2251 -> cost_func=26.8636
# > cl/cd=40.8438 -> cost_func=24.4835
# > cl/cd=34.5230 -> cost_func=28.9662
# > cl/cd=34.2657 -> cost_func=29.1837
# > cl/cd=30.3214 -> cost_func=32.9800
# > cl/cd=35.2398 -> cost_func=28.3770
# > cl/cd=43.5688 -> cost_func=22.9522
# > cl/cd=42.5439 -> cost_func=23.5052
# > cl/cd=47.6523 -> cost_func=20.9853
# > cl/cd=45.6537 -> cost_func=21.9040
# > cl/cd=50.5420 -> cost_func=19.7855
# > cl/cd=48.3360 -> cost_func=20.6885
# > cl/cd=50.5956 -> cost_func=19.7646
# > cl/cd=51.9279 -> cost_func=19.2575
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=52.7129 -> cost_func=18.9707
# > cl/cd=49.3226 -> cost_func=20.2747
# > cl/cd=42.4961 -> cost_func=23.5315
# > cl/cd=39.6828 -> cost_func=25.1998
# > cl/cd=34.8615 -> cost_func=28.6849
# > cl/cd=44.5666 -> cost_func=22.4383
# > cl/cd=44.9196 -> cost_func=22.2620
# > cl/cd=47.9043 -> cost_func=20.8750
# > cl/cd=49.2593 -> cost_func=20.3008
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=47.4204 -> cost_func=21.0880
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=50.0645 -> cost_func=19.9742
# > cl/cd=43.9683 -> cost_func=22.7437
# > cl/cd=53.2264 -> cost_func=18.7877
# > cl/cd=53.4258 -> cost_func=18.7176
# > cl/cd=53.4253 -> cost_func=18.7177
# > cl/cd=49.7377 -> cost_func=20.1055
# > cl/cd=45.2897 -> cost_func=22.0801
# > cl/cd=51.1800 -> cost_func=19.5389
# > cl/cd=47.3182 -> cost_func=21.1335
# > cl/cd=50.1991 -> cost_func=19.9207
# > cl/cd=49.1680 -> cost_func=20.3385
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=51.5241 -> cost_func=19.4084
# > cl/cd=54.2520 -> cost_func=18.4325
# > cl/cd=59.1707 -> cost_func=16.9003
# > cl/cd=54.2022 -> cost_func=18.4494
# > cl/cd=54.1882 -> cost_func=18.4542
# > cl/cd=62.8079 -> cost_func=15.9216
# > cl/cd=57.1541 -> cost_func=17.4966
# > cl/cd=67.3413 -> cost_func=14.8497
# > cl/cd=57.4106 -> cost_func=17.4184
# > cl/cd=65.7555 -> cost_func=15.2078
# > cl/cd=64.5017 -> cost_func=15.5035
# > cl/cd=62.0290 -> cost_func=16.1215
# > cl/cd=64.0209 -> cost_func=15.6199
# > cl/cd=60.8247 -> cost_func=16.4407
# > cl/cd=67.3148 -> cost_func=14.8556
# > cl/cd=72.4337 -> cost_func=13.8057
# > cl/cd=84.8877 -> cost_func=11.7803
# > cl/cd=69.4935 -> cost_func=14.3898
# > cl/cd=69.6774 -> cost_func=14.3519
# > cl/cd=87.8378 -> cost_func=11.3846
# > cl/cd=67.9217 -> cost_func=14.7228
# > cl/cd=86.6851 -> cost_func=11.5360
# > cl/cd=89.7398 -> cost_func=11.1433
# > cl/cd=91.4917 -> cost_func=10.9300
# > cl/cd=85.5401 -> cost_func=11.6904
# > cl/cd=64.7504 -> cost_func=15.4439
# > cl/cd=45.2758 -> cost_func=22.0868
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=66.6124 -> cost_func=15.0122
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=65.7571 -> cost_func=15.2075
# > cl/cd=85.2650 -> cost_func=11.7281
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=80.8615 -> cost_func=12.3668
# > cl/cd=59.6429 -> cost_func=16.7665
# > cl/cd=57.6031 -> cost_func=17.3602
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=54.9469 -> cost_func=18.1994
# > cl/cd=63.4354 -> cost_func=15.7641
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=57.9663 -> cost_func=17.2514
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=56.9870 -> cost_func=17.5479
# > cl/cd=53.2914 -> cost_func=18.7647
# > cl/cd=54.8909 -> cost_func=18.2179
# > cl/cd=58.2075 -> cost_func=17.1799
# > cl/cd=53.9954 -> cost_func=18.5201
# > cl/cd=57.5651 -> cost_func=17.3716
# > cl/cd=55.0000 -> cost_func=18.1818
# > cl/cd=53.9154 -> cost_func=18.5476
# > cl/cd=50.9559 -> cost_func=19.6248
# > cl/cd=48.8310 -> cost_func=20.4788
# > cl/cd=50.7435 -> cost_func=19.7070
# > cl/cd=47.4372 -> cost_func=21.0805
# > cl/cd=46.0911 -> cost_func=21.6962
# > cl/cd=44.4115 -> cost_func=22.5167
# > cl/cd=43.7253 -> cost_func=22.8701
# > cl/cd=45.4717 -> cost_func=21.9917
# > cl/cd=44.9630 -> cost_func=22.2405
# > cl/cd=41.0112 -> cost_func=24.3836
# > cl/cd=37.4141 -> cost_func=26.7279
# > cl/cd=36.3086 -> cost_func=27.5417
# > cl/cd=35.0951 -> cost_func=28.4940
# > cl/cd=33.5680 -> cost_func=29.7902
# > cl/cd=35.9061 -> cost_func=27.8504
# > cl/cd=35.1558 -> cost_func=28.4448
# > cl/cd=37.2488 -> cost_func=26.8465
# > cl/cd=38.5968 -> cost_func=25.9089
# > cl/cd=40.8955 -> cost_func=24.4526
# > cl/cd=38.5861 -> cost_func=25.9160
# > cl/cd=42.6248 -> cost_func=23.4605
# > cl/cd=42.8070 -> cost_func=23.3607
# > cl/cd=42.1110 -> cost_func=23.7468
# > cl/cd=41.9325 -> cost_func=23.8479
# > cl/cd=41.1553 -> cost_func=24.2982
# > cl/cd=41.1249 -> cost_func=24.3162
# > cl/cd=39.9809 -> cost_func=25.0120
# > cl/cd=40.1162 -> cost_func=24.9276
# > cl/cd=40.9825 -> cost_func=24.4007
# > cl/cd=41.7556 -> cost_func=23.9489
# > cl/cd=44.1221 -> cost_func=22.6644
# > cl/cd=43.9070 -> cost_func=22.7754
# > cl/cd=42.9908 -> cost_func=23.2608
# > cl/cd=44.8611 -> cost_func=22.2910
# > cl/cd=45.6449 -> cost_func=21.9083
# > cl/cd=46.4183 -> cost_func=21.5432
# > cl/cd=47.5119 -> cost_func=21.0474
# > cl/cd=46.7269 -> cost_func=21.4009
# > cl/cd=49.2480 -> cost_func=20.3054
# > cl/cd=50.8691 -> cost_func=19.6583
# > cl/cd=53.9214 -> cost_func=18.5455
# > cl/cd=53.8226 -> cost_func=18.5795
# > cl/cd=54.2277 -> cost_func=18.4408
# > cl/cd=54.8583 -> cost_func=18.2288
# > cl/cd=54.5764 -> cost_func=18.3229
# > cl/cd=56.2042 -> cost_func=17.7923
# > cl/cd=57.6476 -> cost_func=17.3468
# > cl/cd=57.3051 -> cost_func=17.4505
# > cl/cd=56.6538 -> cost_func=17.6511
# > cl/cd=57.1083 -> cost_func=17.5106
# > cl/cd=57.6667 -> cost_func=17.3410
# > cl/cd=61.6489 -> cost_func=16.2209
# > cl/cd=59.9141 -> cost_func=16.6906
# > cl/cd=55.4304 -> cost_func=18.0406
# > cl/cd=59.1276 -> cost_func=16.9126
# > cl/cd=60.3337 -> cost_func=16.5745
# > cl/cd=60.6968 -> cost_func=16.4753
# > cl/cd=63.0120 -> cost_func=15.8700
# > cl/cd=63.2647 -> cost_func=15.8066
# > cl/cd=66.7335 -> cost_func=14.9850
# > cl/cd=65.2400 -> cost_func=15.3280
# > cl/cd=61.5600 -> cost_func=16.2443
# > cl/cd=61.8182 -> cost_func=16.1765
# > cl/cd=60.6256 -> cost_func=16.4947
# > cl/cd=61.8980 -> cost_func=16.1556
# > cl/cd=65.6135 -> cost_func=15.2408
# > cl/cd=64.4051 -> cost_func=15.5267
# > cl/cd=62.2103 -> cost_func=16.0745
# > cl/cd=65.2295 -> cost_func=15.3305
# > cl/cd=68.2988 -> cost_func=14.6415
# > cl/cd=70.2700 -> cost_func=14.2308
# > cl/cd=69.4863 -> cost_func=14.3913
# > cl/cd=74.2308 -> cost_func=13.4715
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=70.2665 -> cost_func=14.2315
# > cl/cd=72.2912 -> cost_func=13.8329
# > cl/cd=70.5940 -> cost_func=14.1655
# > cl/cd=71.9645 -> cost_func=13.8957
# > cl/cd=72.6396 -> cost_func=13.7666
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=113.5690 -> cost_func=8.8052
# > cl/cd=112.2635 -> cost_func=8.9076
# > cl/cd=71.3103 -> cost_func=14.0232
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=111.5228 -> cost_func=8.9668
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=73.3371 -> cost_func=13.6357
# > cl/cd=62.0385 -> cost_func=16.1190
# > cl/cd=71.5262 -> cost_func=13.9809
# > cl/cd=107.7143 -> cost_func=9.2838
# > cl/cd=113.7902 -> cost_func=8.7881
# > cl/cd=111.9393 -> cost_func=8.9334
# > cl/cd=109.1919 -> cost_func=9.1582
# > cl/cd=108.7624 -> cost_func=9.1944
# > cl/cd=104.0704 -> cost_func=9.6089
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=105.0918 -> cost_func=9.5155
# > cl/cd=105.4305 -> cost_func=9.4849
# > cl/cd=108.1759 -> cost_func=9.2442
# > cl/cd=103.7583 -> cost_func=9.6378
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=113.8511 -> cost_func=8.7834
# > cl/cd=114.7368 -> cost_func=8.7156
# > cl/cd=109.0538 -> cost_func=9.1698
# > cl/cd=113.8449 -> cost_func=8.7839
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=111.4358 -> cost_func=8.9738
# > cl/cd=107.2835 -> cost_func=9.3211
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=118.2234 -> cost_func=8.4586
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=115.0248 -> cost_func=8.6938
# > cl/cd=112.8856 -> cost_func=8.8585
# > cl/cd=116.0762 -> cost_func=8.6150
# > cl/cd=115.0820 -> cost_func=8.6895
# > cl/cd=69.8994 -> cost_func=14.3063
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=114.9660 -> cost_func=8.6982
# > cl/cd=113.7759 -> cost_func=8.7892
# > cl/cd=113.1507 -> cost_func=8.8378
# > cl/cd=112.0517 -> cost_func=8.9244
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=114.2982 -> cost_func=8.7490
# > cl/cd=111.2652 -> cost_func=8.9875
# > cl/cd=106.3606 -> cost_func=9.4020
# > cl/cd=110.8854 -> cost_func=9.0183
# > cl/cd=102.7888 -> cost_func=9.7287
# > cl/cd=113.1304 -> cost_func=8.8394
# > cl/cd=106.5753 -> cost_func=9.3830
# > cl/cd=107.7375 -> cost_func=9.2818
# > cl/cd=109.8787 -> cost_func=9.1009
# > cl/cd=103.7050 -> cost_func=9.6427
# > cl/cd=106.8142 -> cost_func=9.3621
# > cl/cd=102.3698 -> cost_func=9.7685
# > cl/cd=104.8454 -> cost_func=9.5379
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=101.3810 -> cost_func=9.8638
# > cl/cd=52.7649 -> cost_func=18.9520
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=55.6639 -> cost_func=17.9650
# > cl/cd=100.9612 -> cost_func=9.9048
# > cl/cd=98.6689 -> cost_func=10.1349
# > cl/cd=96.0461 -> cost_func=10.4117
# > cl/cd=92.8736 -> cost_func=10.7673
# > cl/cd=98.4628 -> cost_func=10.1561
# > cl/cd=100.6040 -> cost_func=9.9400
# > cl/cd=100.0172 -> cost_func=9.9983
# > cl/cd=97.4570 -> cost_func=10.2609
# > cl/cd=97.6410 -> cost_func=10.2416
# > cl/cd=67.9114 -> cost_func=14.7251
# > cl/cd=101.9316 -> cost_func=9.8105
# > cl/cd=102.1151 -> cost_func=9.7929
# > cl/cd=96.7295 -> cost_func=10.3381
# > cl/cd=94.7819 -> cost_func=10.5505
# > cl/cd=97.7349 -> cost_func=10.2318
# > cl/cd=92.9139 -> cost_func=10.7627
# > cl/cd=88.4396 -> cost_func=11.3072
# > cl/cd=95.6158 -> cost_func=10.4585
# > cl/cd=94.0328 -> cost_func=10.6346
# > cl/cd=91.5385 -> cost_func=10.9244
# > cl/cd=91.5200 -> cost_func=10.9266
# > cl/cd=88.9062 -> cost_func=11.2478
# > cl/cd=87.2071 -> cost_func=11.4670
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=90.4013 -> cost_func=11.0618
# > cl/cd=90.7667 -> cost_func=11.0173
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=80.2412 -> cost_func=12.4624
# > cl/cd=72.2477 -> cost_func=13.8413
# > cl/cd=85.3523 -> cost_func=11.7161
# > cl/cd=84.2736 -> cost_func=11.8661
# > cl/cd=81.9702 -> cost_func=12.1996
# > cl/cd=81.1054 -> cost_func=12.3296
# > cl/cd=77.7205 -> cost_func=12.8666
# > cl/cd=79.6068 -> cost_func=12.5617
# > cl/cd=75.3613 -> cost_func=13.2694
# > cl/cd=72.8188 -> cost_func=13.7327
# > cl/cd=75.0754 -> cost_func=13.3199
# > cl/cd=70.4882 -> cost_func=14.1868
# > cl/cd=78.3916 -> cost_func=12.7565
# > cl/cd=77.5885 -> cost_func=12.8885
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=78.6575 -> cost_func=12.7133
# > cl/cd=79.9828 -> cost_func=12.5027
# > cl/cd=79.4825 -> cost_func=12.5814
# > cl/cd=58.6047 -> cost_func=17.0635
# > cl/cd=61.5405 -> cost_func=16.2495
# > cl/cd=82.9443 -> cost_func=12.0563
# > cl/cd=83.7276 -> cost_func=11.9435
# > cl/cd=66.9400 -> cost_func=14.9388
# > cl/cd=82.7807 -> cost_func=12.0801
# > cl/cd=73.5680 -> cost_func=13.5929
# > cl/cd=69.2037 -> cost_func=14.4501
# > cl/cd=78.1141 -> cost_func=12.8018
# > cl/cd=82.5249 -> cost_func=12.1176
# > cl/cd=85.9669 -> cost_func=11.6324
# > cl/cd=83.8376 -> cost_func=11.9278
# > cl/cd=47.9423 -> cost_func=20.8584
# > cl/cd=88.1072 -> cost_func=11.3498
# > cl/cd=88.0880 -> cost_func=11.3523
# > cl/cd=91.6034 -> cost_func=10.9166
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=92.1593 -> cost_func=10.8508
# > cl/cd=92.1025 -> cost_func=10.8575
# > cl/cd=91.8537 -> cost_func=10.8869
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=96.6957 -> cost_func=10.3417
# > cl/cd=41.9802 -> cost_func=23.8208
# > cl/cd=43.7489 -> cost_func=22.8577
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=49.7604 -> cost_func=20.0963
# > cl/cd=51.0485 -> cost_func=19.5892
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=51.8418 -> cost_func=19.2894
# > cl/cd=48.0742 -> cost_func=20.8012
# > cl/cd=51.1294 -> cost_func=19.5582
# > cl/cd=49.6024 -> cost_func=20.1603
# > cl/cd=88.4509 -> cost_func=11.3057
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=96.6667 -> cost_func=10.3448
# > cl/cd=91.1506 -> cost_func=10.9709
# > cl/cd=94.9828 -> cost_func=10.5282
# > cl/cd=89.2308 -> cost_func=11.2069
# > cl/cd=84.8896 -> cost_func=11.7800
# > cl/cd=89.1419 -> cost_func=11.2181
# > cl/cd=89.1002 -> cost_func=11.2233
# > cl/cd=42.5717 -> cost_func=23.4898
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=82.1928 -> cost_func=12.1665
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=90.8644 -> cost_func=11.0054
# > cl/cd=94.0296 -> cost_func=10.6349
# > cl/cd=90.1948 -> cost_func=11.0871
# > cl/cd=87.2578 -> cost_func=11.4603
# > cl/cd=95.6988 -> cost_func=10.4495
# > cl/cd=97.9608 -> cost_func=10.2082
# > cl/cd=99.0851 -> cost_func=10.0923
# > cl/cd=100.2525 -> cost_func=9.9748
# > cl/cd=51.9615 -> cost_func=19.2450
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=49.9028 -> cost_func=20.0389
# > cl/cd=52.8614 -> cost_func=18.9174
# > cl/cd=95.1520 -> cost_func=10.5095
# > cl/cd=99.0792 -> cost_func=10.0929
# > cl/cd=49.2956 -> cost_func=20.2858
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=96.7391 -> cost_func=10.3371
# > cl/cd=91.5397 -> cost_func=10.9242
# > cl/cd=90.5357 -> cost_func=11.0454
# > cl/cd=87.8213 -> cost_func=11.3868
# > cl/cd=83.5401 -> cost_func=11.9703
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=90.4854 -> cost_func=11.0515
# > cl/cd=87.3543 -> cost_func=11.4476
# > cl/cd=83.2362 -> cost_func=12.0140
# > cl/cd=86.1527 -> cost_func=11.6073
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=85.0385 -> cost_func=11.7594
# > cl/cd=86.7670 -> cost_func=11.5251
# > cl/cd=90.9462 -> cost_func=10.9955
# > cl/cd=86.9378 -> cost_func=11.5025
# > cl/cd=89.0969 -> cost_func=11.2237
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=86.6288 -> cost_func=11.5435
# > cl/cd=91.7547 -> cost_func=10.8986
# > cl/cd=84.4378 -> cost_func=11.8430
# > cl/cd=89.5390 -> cost_func=11.1683
# > cl/cd=90.0906 -> cost_func=11.0999
# > cl/cd=91.2558 -> cost_func=10.9582
# > cl/cd=88.0982 -> cost_func=11.3510
# > cl/cd=91.8396 -> cost_func=10.8885
# > cl/cd=95.4128 -> cost_func=10.4808
# > cl/cd=97.5909 -> cost_func=10.2469
# > cl/cd=99.4770 -> cost_func=10.0526
# > cl/cd=99.1256 -> cost_func=10.0882
# > cl/cd=98.3252 -> cost_func=10.1703
# > cl/cd=100.9709 -> cost_func=9.9038
# > cl/cd=104.2764 -> cost_func=9.5899
# > cl/cd=93.7269 -> cost_func=10.6693
# > cl/cd=105.5207 -> cost_func=9.4768
# > cl/cd=96.7249 -> cost_func=10.3386
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=102.6786 -> cost_func=9.7391
# > cl/cd=110.7846 -> cost_func=9.0265
# > cl/cd=108.3475 -> cost_func=9.2296
# > cl/cd=109.5537 -> cost_func=9.1279
# > cl/cd=114.9577 -> cost_func=8.6989
# > cl/cd=113.7398 -> cost_func=8.7920
# > cl/cd=114.0199 -> cost_func=8.7704
# > cl/cd=118.9112 -> cost_func=8.4096
# > cl/cd=103.9357 -> cost_func=9.6213
# > cl/cd=118.9508 -> cost_func=8.4068
# > cl/cd=112.0399 -> cost_func=8.9254
# > cl/cd=117.0128 -> cost_func=8.5461
# > cl/cd=100.8659 -> cost_func=9.9142
# > cl/cd=117.8282 -> cost_func=8.4869
# > cl/cd=121.1200 -> cost_func=8.2563
# > cl/cd=123.7821 -> cost_func=8.0787
# > cl/cd=124.1680 -> cost_func=8.0536
# > cl/cd=120.7903 -> cost_func=8.2788
# > cl/cd=125.9968 -> cost_func=7.9367
# > cl/cd=125.7792 -> cost_func=7.9504
# > cl/cd=124.1148 -> cost_func=8.0571
# > cl/cd=127.2638 -> cost_func=7.8577
# > cl/cd=127.3520 -> cost_func=7.8523
# > cl/cd=122.6171 -> cost_func=8.1555
# > cl/cd=124.2454 -> cost_func=8.0486
# > cl/cd=123.9650 -> cost_func=8.0668
# > cl/cd=129.6880 -> cost_func=7.7108
# > cl/cd=130.4455 -> cost_func=7.6660
# > cl/cd=128.9327 -> cost_func=7.7560
# > cl/cd=126.8019 -> cost_func=7.8863
# > cl/cd=135.7401 -> cost_func=7.3670
# > cl/cd=135.9841 -> cost_func=7.3538
# > cl/cd=134.1280 -> cost_func=7.4556
# > cl/cd=134.8666 -> cost_func=7.4147
# > cl/cd=130.1541 -> cost_func=7.6832
# > cl/cd=134.8118 -> cost_func=7.4177
# > cl/cd=129.9371 -> cost_func=7.6960
# > cl/cd=130.8410 -> cost_func=7.6429
# > cl/cd=136.0870 -> cost_func=7.3482
# > cl/cd=137.1237 -> cost_func=7.2927
# > cl/cd=0.0100 -> cost_func=100000.0000
# > cl/cd=139.7882 -> cost_func=7.1537
# > cl/cd=144.3566 -> cost_func=6.9273

# %%
opt.results()
# Out:
# +------------------------ RESULTS -------------------------+
#
#       opt.mode: continuous
# cooling sched.: linear additive cooling
#        damping: 0.01
#
#   initial temp: 2.5
#     final temp: 0.005000
#      max steps: 500
#     final step: 500
#
#   final energy: 6.927290
#
# +-------------------------- END ---------------------------+

# %%
# initial
# note that the initial airfoil did produce just the smallest bit of lift 
# which is why the cost function is greater than zero...
cost_function(opt.x0)
# Out:
# > cl/cd=0.3166 -> cost_func=3158.8235
# 3158.823529411765

# %%
# final
cost_function(opt.best_state)
# Out:
# > cl/cd=144.3566 -> cost_func=6.9273
# 6.927290301793577

# %%
airfoil_initial = bezier_airfoil(x_cos, munge_ctlpts(opt.x0, 3, 3))
airfoil_final   = bezier_airfoil(x_cos, munge_ctlpts(opt.best_state, 3, 3))

fig, ax = plt.subplots(figsize=(14,5))

x_initial, y_initial=zip(*airfoil_initial)
x_final, y_final=zip(*airfoil_final)

plt.plot(x_initial, y_initial, label='initial', linestyle='--')
plt.plot(x_final, y_final, label='final')
plt.title('results')

plt.legend()
plt.ylim(-0.15, 0.15)
ax.set_aspect('equal')
plt.show()
